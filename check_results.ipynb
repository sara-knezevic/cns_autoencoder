# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import re

# %%
def extract_parameters(filename):
    # Define the regular expression pattern to extract the parameters
    pattern = r'mse_corr(?P<mse_corr>[\d\.]+)_diff(?P<diff>[\d\.]+)_ssim(?P<ssim>[\d\.]+)_div(?P<div>[\d\.]+)\.csv'
    
    # Match the pattern against the filename
    match = re.match(pattern, filename)
    
    # Extract the parameters and convert them to float
    if match:
        params = {
            'corr': float(match.group('mse_corr')),
            'diff': float(match.group('diff')),
            'ssim': float(match.group('ssim')),
            'div': float(match.group('div'))
        }
        return params
    else:
        return None

# %%
# Define the directory containing the CSV files
dir = './results'
files = os.listdir(dir)

# Define the columns of the DataFrame
cols = ['lat', 'lbd', 'file_name', 'train_loss', 'val_loss', 'fc_diff_train', 'fc_diff_val', 'corr_train', 'corr_val']
df = pd.DataFrame(columns=cols)

# Iterate through each file in the directory
for file in files:
    if file.endswith('.csv'):
        # Read the CSV file into a temporary DataFrame
        temp_df = pd.read_csv(os.path.join(dir, file))
        
        # Add a column for the file name
        temp_df['file_name'] = file
        
        # Extract parameters from the file name and add them as columns
        params = extract_parameters(file)
        if params is not None:
            for key, value in params.items():
                temp_df[key] = value
        
        # Append the temporary DataFrame to the main DataFrame
        df = pd.concat([df, temp_df], ignore_index=True)

# drop lbd column
df = df.drop('lbd', axis=1)

# Print the resulting DataFrame
df.head()
# Out:
# /var/folders/g_/2zpqj2h15j734d8xg44xmq040000gn/T/ipykernel_46275/916567518.py:25: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, temp_df], ignore_index=True)
#   lat                                        file_name  train_loss  val_loss  \
# 0   6  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv    1.002070  0.873928
# 1   6  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv    0.796497  0.691415
# 2   6  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv    0.673552  0.593045
# 3   6  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv    0.630108  0.563485
# 4   6  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv    0.608795  0.544221
#
#    fc_diff_train  fc_diff_val  corr_train  corr_val    corr    diff    ssim  \
# 0       0.169593     0.174031    0.257627  0.263212  0.0005  0.0005  0.0005
# 1       0.169776     0.163963    0.367836  0.266597  0.0005  0.0005  0.0005
# 2       0.161773     0.186425    0.392346  0.272627  0.0005  0.0005  0.0005
# 3       0.145922     0.147300    0.437058  0.351155  0.0005  0.0005  0.0005
# 4       0.125267     0.119031    0.460977  0.398583  0.0005  0.0005  0.0005
#
#    div
# 0  0.1
# 1  0.1
# 2  0.1
# 3  0.1
# 4  0.1

# %%
# Group by the hyperparameters and latent dimension
grouped = df.groupby(['lat', 'corr', 'diff', 'ssim', 'div'])

# Find the best performing run for each group based on the lowest validation loss
best_runs = grouped.apply(lambda x: x.loc[x['val_loss'].idxmin()])

# Reset index to get a clean DataFrame
best_runs.reset_index(drop=True, inplace=True)

# %%
best_runs
# Out:
#      lat                                        file_name  train_loss  \
# 0      6                 mse_corr0_diff0_ssim0_div0.1.csv    0.459475
# 1      6            mse_corr0_diff0_ssim0.0005_div0.1.csv    0.447489
# 2      6             mse_corr0_diff0_ssim0.005_div0.1.csv    0.411772
# 3      6            mse_corr0_diff0.0005_ssim0_div0.1.csv    0.442642
# 4      6       mse_corr0_diff0.0005_ssim0.0005_div0.1.csv    0.414113
# ..   ...                                              ...         ...
# 160   16  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv    0.278120
# 161   16             mse_corr0.005_diff0_ssim0_div0.1.csv    0.305363
# 162   16         mse_corr0.005_diff0_ssim0.005_div0.1.csv    0.242290
# 163   16         mse_corr0.005_diff0.005_ssim0_div0.1.csv    0.275167
# 164   16     mse_corr0.005_diff0.005_ssim0.005_div0.1.csv    0.280771
#
#      val_loss  fc_diff_train  fc_diff_val  corr_train  corr_val    corr  \
# 0    0.427357       0.079160     0.033135    0.567320  0.631136  0.0000
# 1    0.431571       0.065162     0.043013    0.544203  0.559863  0.0000
# 2    0.407401       0.090612     0.069676    0.509739  0.542241  0.0000
# 3    0.429785       0.070269     0.045401    0.568069  0.636237  0.0000
# 4    0.411274       0.077295     0.073527    0.496637  0.494534  0.0000
# ..        ...            ...          ...         ...       ...     ...
# 160  0.241780       0.044463     0.028533    0.683368  0.673939  0.0005
# 161  0.265618       0.041162     0.030320    0.668523  0.641925  0.0050
# 162  0.203124       0.047995     0.028253    0.686892  0.651599  0.0050
# 163  0.243343       0.038975     0.026175    0.690727  0.721439  0.0050
# 164  0.246991       0.042639     0.020182    0.692823  0.708100  0.0050
#
#        diff    ssim  div
# 0    0.0000  0.0000  0.1
# 1    0.0000  0.0005  0.1
# 2    0.0000  0.0050  0.1
# 3    0.0005  0.0000  0.1
# 4    0.0005  0.0005  0.1
# ..      ...     ...  ...
# 160  0.0005  0.0005  0.1
# 161  0.0000  0.0000  0.1
# 162  0.0000  0.0050  0.1
# 163  0.0050  0.0000  0.1
# 164  0.0050  0.0050  0.1
#
# [165 rows x 12 columns]

# %%
top_performers = best_runs.sort_values(by='val_loss').head(10)
top_performers
# Out:
#      lat                                   file_name  train_loss  val_loss  \
# 136   15       mse_corr0_diff0_ssim0.0005_div0.1.csv    0.235193  0.196677
# 148   15    mse_corr0.005_diff0.005_ssim0_div0.1.csv    0.237035  0.198275
# 162   16    mse_corr0.005_diff0_ssim0.005_div0.1.csv    0.242290  0.203124
# 127   14       mse_corr0.0005_diff0_ssim0_div0.1.csv    0.256543  0.209588
# 138   15       mse_corr0_diff0.0005_ssim0_div0.1.csv    0.250726  0.211179
# 121   14       mse_corr0_diff0_ssim0.0005_div0.1.csv    0.252623  0.213478
# 159   16  mse_corr0.0005_diff0.0005_ssim0_div0.1.csv    0.254550  0.213886
# 157   16       mse_corr0.0005_diff0_ssim0_div0.1.csv    0.252209  0.215140
# 143   15  mse_corr0.0005_diff0_ssim0.0005_div0.1.csv    0.258585  0.216277
# 128   14  mse_corr0.0005_diff0_ssim0.0005_div0.1.csv    0.256077  0.216935
#
#      fc_diff_train  fc_diff_val  corr_train  corr_val    corr    diff    ssim  \
# 136       0.041319     0.020949    0.696303  0.745745  0.0000  0.0000  0.0005
# 148       0.041711     0.020396    0.706941  0.743455  0.0050  0.0050  0.0000
# 162       0.047995     0.028253    0.686892  0.651599  0.0050  0.0000  0.0050
# 127       0.038311     0.018061    0.695951  0.764503  0.0005  0.0000  0.0000
# 138       0.034824     0.016137    0.699583  0.780684  0.0000  0.0005  0.0000
# 121       0.039493     0.027148    0.735576  0.749088  0.0000  0.0000  0.0005
# 159       0.043669     0.029926    0.689753  0.668147  0.0005  0.0005  0.0000
# 157       0.038210     0.022762    0.710146  0.730936  0.0005  0.0000  0.0000
# 143       0.038412     0.020534    0.714709  0.760300  0.0005  0.0000  0.0005
# 128       0.036846     0.025918    0.706146  0.704655  0.0005  0.0000  0.0005
#
#      div
# 136  0.1
# 148  0.1
# 162  0.1
# 127  0.1
# 138  0.1
# 121  0.1
# 159  0.1
# 157  0.1
# 143  0.1
# 128  0.1

# %%
top_performers_corr = best_runs.sort_values(by='corr_val', ascending=False).head(10)
top_performers_corr
# Out:
#      lat                                     file_name  train_loss  val_loss  \
# 138   15         mse_corr0_diff0.0005_ssim0_div0.1.csv    0.250726  0.211179
# 149   15  mse_corr0.005_diff0.005_ssim0.005_div0.1.csv    0.265260  0.231014
# 98    12    mse_corr0.0005_diff0_ssim0.0005_div0.1.csv    0.286353  0.251982
# 127   14         mse_corr0.0005_diff0_ssim0_div0.1.csv    0.256543  0.209588
# 90    12              mse_corr0_diff0_ssim0_div0.1.csv    0.293557  0.257944
# 77    11          mse_corr0_diff0_ssim0.005_div0.1.csv    0.315493  0.285775
# 143   15    mse_corr0.0005_diff0_ssim0.0005_div0.1.csv    0.258585  0.216277
# 122   14          mse_corr0_diff0_ssim0.005_div0.1.csv    0.269638  0.235933
# 126   14      mse_corr0_diff0.005_ssim0.005_div0.1.csv    0.255772  0.220148
# 93    12         mse_corr0_diff0.0005_ssim0_div0.1.csv    0.291860  0.258191
#
#      fc_diff_train  fc_diff_val  corr_train  corr_val    corr    diff    ssim  \
# 138       0.034824     0.016137    0.699583  0.780684  0.0000  0.0005  0.0000
# 149       0.040395     0.019760    0.692458  0.771465  0.0050  0.0050  0.0050
# 98        0.042611     0.017668    0.663266  0.768460  0.0005  0.0000  0.0005
# 127       0.038311     0.018061    0.695951  0.764503  0.0005  0.0000  0.0000
# 90        0.038378     0.017529    0.694973  0.762429  0.0000  0.0000  0.0000
# 77        0.043501     0.023665    0.685423  0.761611  0.0000  0.0000  0.0050
# 143       0.038412     0.020534    0.714709  0.760300  0.0005  0.0000  0.0005
# 122       0.043504     0.019354    0.700798  0.758743  0.0000  0.0000  0.0050
# 126       0.041344     0.016828    0.681446  0.756508  0.0000  0.0050  0.0050
# 93        0.040221     0.016625    0.674616  0.753459  0.0000  0.0005  0.0000
#
#      div
# 138  0.1
# 149  0.1
# 98   0.1
# 127  0.1
# 90   0.1
# 77   0.1
# 143  0.1
# 122  0.1
# 126  0.1
# 93   0.1

# %%
best_runs_no_corr = best_runs[(best_runs['corr'] == 0) & (best_runs['diff'] == 0) & (best_runs['ssim'] == 0)]
best_runs_no_corr
# Out:
#      lat                         file_name  train_loss  val_loss  \
# 0      6  mse_corr0_diff0_ssim0_div0.1.csv    0.459475  0.427357
# 15     7  mse_corr0_diff0_ssim0_div0.1.csv    0.416366  0.396605
# 30     8  mse_corr0_diff0_ssim0_div0.1.csv    0.349174  0.337708
# 45     9  mse_corr0_diff0_ssim0_div0.1.csv    0.361151  0.337661
# 60    10  mse_corr0_diff0_ssim0_div0.1.csv    0.322559  0.296315
# 75    11  mse_corr0_diff0_ssim0_div0.1.csv    0.302080  0.273958
# 90    12  mse_corr0_diff0_ssim0_div0.1.csv    0.293557  0.257944
# 105   13  mse_corr0_diff0_ssim0_div0.1.csv    0.292193  0.263132
# 120   14  mse_corr0_diff0_ssim0_div0.1.csv    0.257622  0.226449
# 135   15  mse_corr0_diff0_ssim0_div0.1.csv    0.255873  0.219780
# 150   16  mse_corr0_diff0_ssim0_div0.1.csv    0.255030  0.227376
#
#      fc_diff_train  fc_diff_val  corr_train  corr_val  corr  diff  ssim  div
# 0         0.079160     0.033135    0.567320  0.631136   0.0   0.0   0.0  0.1
# 15        0.064008     0.040547    0.581604  0.580230   0.0   0.0   0.0  0.1
# 30        0.067203     0.046444    0.566891  0.590643   0.0   0.0   0.0  0.1
# 45        0.054643     0.044604    0.602813  0.664729   0.0   0.0   0.0  0.1
# 60        0.047704     0.045707    0.655121  0.692589   0.0   0.0   0.0  0.1
# 75        0.044765     0.029479    0.681217  0.676930   0.0   0.0   0.0  0.1
# 90        0.038378     0.017529    0.694973  0.762429   0.0   0.0   0.0  0.1
# 105       0.038932     0.045718    0.704519  0.652193   0.0   0.0   0.0  0.1
# 120       0.035438     0.028497    0.722688  0.689381   0.0   0.0   0.0  0.1
# 135       0.041905     0.031487    0.692200  0.671201   0.0   0.0   0.0  0.1
# 150       0.047417     0.035434    0.696326  0.704610   0.0   0.0   0.0  0.1

# %%
top_performers_same_params = best_runs.groupby(['corr', 'diff', 'ssim', 'div']).apply(lambda x: x.loc[x['val_loss'].idxmin()])
top_performers_same_params
# Out:
#                           lat  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1   15
#               0.0005 0.1   15
#               0.0050 0.1   15
#        0.0005 0.0000 0.1   15
#               0.0005 0.1   15
#        0.0050 0.0000 0.1   16
#               0.0050 0.1   14
# 0.0005 0.0000 0.0000 0.1   14
#               0.0005 0.1   15
#        0.0005 0.0000 0.1   16
#               0.0005 0.1   16
# 0.0050 0.0000 0.0000 0.1   13
#               0.0050 0.1   16
#        0.0050 0.0000 0.1   15
#               0.0050 0.1   15
#
#                                                                 file_name  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1                 mse_corr0_diff0_ssim0_div0.1.csv
#               0.0005 0.1            mse_corr0_diff0_ssim0.0005_div0.1.csv
#               0.0050 0.1             mse_corr0_diff0_ssim0.005_div0.1.csv
#        0.0005 0.0000 0.1            mse_corr0_diff0.0005_ssim0_div0.1.csv
#               0.0005 0.1       mse_corr0_diff0.0005_ssim0.0005_div0.1.csv
#        0.0050 0.0000 0.1             mse_corr0_diff0.005_ssim0_div0.1.csv
#               0.0050 0.1         mse_corr0_diff0.005_ssim0.005_div0.1.csv
# 0.0005 0.0000 0.0000 0.1            mse_corr0.0005_diff0_ssim0_div0.1.csv
#               0.0005 0.1       mse_corr0.0005_diff0_ssim0.0005_div0.1.csv
#        0.0005 0.0000 0.1       mse_corr0.0005_diff0.0005_ssim0_div0.1.csv
#               0.0005 0.1  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv
# 0.0050 0.0000 0.0000 0.1             mse_corr0.005_diff0_ssim0_div0.1.csv
#               0.0050 0.1         mse_corr0.005_diff0_ssim0.005_div0.1.csv
#        0.0050 0.0000 0.1         mse_corr0.005_diff0.005_ssim0_div0.1.csv
#               0.0050 0.1     mse_corr0.005_diff0.005_ssim0.005_div0.1.csv
#
#                           train_loss  val_loss  fc_diff_train  fc_diff_val  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1    0.255873  0.219780       0.041905     0.031487
#               0.0005 0.1    0.235193  0.196677       0.041319     0.020949
#               0.0050 0.1    0.259459  0.220312       0.041850     0.037232
#        0.0005 0.0000 0.1    0.250726  0.211179       0.034824     0.016137
#               0.0005 0.1    0.257460  0.218879       0.040891     0.023640
#        0.0050 0.0000 0.1    0.271410  0.233412       0.043339     0.027902
#               0.0050 0.1    0.255772  0.220148       0.041344     0.016828
# 0.0005 0.0000 0.0000 0.1    0.256543  0.209588       0.038311     0.018061
#               0.0005 0.1    0.258585  0.216277       0.038412     0.020534
#        0.0005 0.0000 0.1    0.254550  0.213886       0.043669     0.029926
#               0.0005 0.1    0.278120  0.241780       0.044463     0.028533
# 0.0050 0.0000 0.0000 0.1    0.275631  0.242079       0.046507     0.026104
#               0.0050 0.1    0.242290  0.203124       0.047995     0.028253
#        0.0050 0.0000 0.1    0.237035  0.198275       0.041711     0.020396
#               0.0050 0.1    0.265260  0.231014       0.040395     0.019760
#
#                           corr_train  corr_val    corr    diff    ssim  div
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1    0.692200  0.671201  0.0000  0.0000  0.0000  0.1
#               0.0005 0.1    0.696303  0.745745  0.0000  0.0000  0.0005  0.1
#               0.0050 0.1    0.676668  0.722281  0.0000  0.0000  0.0050  0.1
#        0.0005 0.0000 0.1    0.699583  0.780684  0.0000  0.0005  0.0000  0.1
#               0.0005 0.1    0.692287  0.729939  0.0000  0.0005  0.0005  0.1
#        0.0050 0.0000 0.1    0.660661  0.667959  0.0000  0.0050  0.0000  0.1
#               0.0050 0.1    0.681446  0.756508  0.0000  0.0050  0.0050  0.1
# 0.0005 0.0000 0.0000 0.1    0.695951  0.764503  0.0005  0.0000  0.0000  0.1
#               0.0005 0.1    0.714709  0.760300  0.0005  0.0000  0.0005  0.1
#        0.0005 0.0000 0.1    0.689753  0.668147  0.0005  0.0005  0.0000  0.1
#               0.0005 0.1    0.683368  0.673939  0.0005  0.0005  0.0005  0.1
# 0.0050 0.0000 0.0000 0.1    0.680738  0.716678  0.0050  0.0000  0.0000  0.1
#               0.0050 0.1    0.686892  0.651599  0.0050  0.0000  0.0050  0.1
#        0.0050 0.0000 0.1    0.706941  0.743455  0.0050  0.0050  0.0000  0.1
#               0.0050 0.1    0.692458  0.771465  0.0050  0.0050  0.0050  0.1

# %%
top_performers_same_params = best_runs.groupby(['corr', 'diff', 'ssim', 'div']).apply(lambda x: x.loc[x['corr_val'].idxmax()])
top_performers_same_params
# Out:
#                           lat  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1   12
#               0.0005 0.1   14
#               0.0050 0.1   11
#        0.0005 0.0000 0.1   15
#               0.0005 0.1   14
#        0.0050 0.0000 0.1    7
#               0.0050 0.1   14
# 0.0005 0.0000 0.0000 0.1   14
#               0.0005 0.1   12
#        0.0005 0.0000 0.1   11
#               0.0005 0.1   12
# 0.0050 0.0000 0.0000 0.1   11
#               0.0050 0.1   14
#        0.0050 0.0000 0.1   15
#               0.0050 0.1   15
#
#                                                                 file_name  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1                 mse_corr0_diff0_ssim0_div0.1.csv
#               0.0005 0.1            mse_corr0_diff0_ssim0.0005_div0.1.csv
#               0.0050 0.1             mse_corr0_diff0_ssim0.005_div0.1.csv
#        0.0005 0.0000 0.1            mse_corr0_diff0.0005_ssim0_div0.1.csv
#               0.0005 0.1       mse_corr0_diff0.0005_ssim0.0005_div0.1.csv
#        0.0050 0.0000 0.1             mse_corr0_diff0.005_ssim0_div0.1.csv
#               0.0050 0.1         mse_corr0_diff0.005_ssim0.005_div0.1.csv
# 0.0005 0.0000 0.0000 0.1            mse_corr0.0005_diff0_ssim0_div0.1.csv
#               0.0005 0.1       mse_corr0.0005_diff0_ssim0.0005_div0.1.csv
#        0.0005 0.0000 0.1       mse_corr0.0005_diff0.0005_ssim0_div0.1.csv
#               0.0005 0.1  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv
# 0.0050 0.0000 0.0000 0.1             mse_corr0.005_diff0_ssim0_div0.1.csv
#               0.0050 0.1         mse_corr0.005_diff0_ssim0.005_div0.1.csv
#        0.0050 0.0000 0.1         mse_corr0.005_diff0.005_ssim0_div0.1.csv
#               0.0050 0.1     mse_corr0.005_diff0.005_ssim0.005_div0.1.csv
#
#                           train_loss  val_loss  fc_diff_train  fc_diff_val  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1    0.293557  0.257944       0.038378     0.017529
#               0.0005 0.1    0.252623  0.213478       0.039493     0.027148
#               0.0050 0.1    0.315493  0.285775       0.043501     0.023665
#        0.0005 0.0000 0.1    0.250726  0.211179       0.034824     0.016137
#               0.0005 0.1    0.272213  0.239326       0.039657     0.023367
#        0.0050 0.0000 0.1    0.425815  0.397740       0.074891     0.024668
#               0.0050 0.1    0.255772  0.220148       0.041344     0.016828
# 0.0005 0.0000 0.0000 0.1    0.256543  0.209588       0.038311     0.018061
#               0.0005 0.1    0.286353  0.251982       0.042611     0.017668
#        0.0005 0.0000 0.1    0.319585  0.289441       0.046520     0.020741
#               0.0005 0.1    0.295052  0.263159       0.050977     0.027823
# 0.0050 0.0000 0.0000 0.1    0.309297  0.274103       0.046060     0.018986
#               0.0050 0.1    0.258150  0.227930       0.045178     0.020162
#        0.0050 0.0000 0.1    0.237035  0.198275       0.041711     0.020396
#               0.0050 0.1    0.265260  0.231014       0.040395     0.019760
#
#                           corr_train  corr_val    corr    diff    ssim  div
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1    0.694973  0.762429  0.0000  0.0000  0.0000  0.1
#               0.0005 0.1    0.735576  0.749088  0.0000  0.0000  0.0005  0.1
#               0.0050 0.1    0.685423  0.761611  0.0000  0.0000  0.0050  0.1
#        0.0005 0.0000 0.1    0.699583  0.780684  0.0000  0.0005  0.0000  0.1
#               0.0005 0.1    0.679432  0.746251  0.0000  0.0005  0.0005  0.1
#        0.0050 0.0000 0.1    0.576361  0.712420  0.0000  0.0050  0.0000  0.1
#               0.0050 0.1    0.681446  0.756508  0.0000  0.0050  0.0050  0.1
# 0.0005 0.0000 0.0000 0.1    0.695951  0.764503  0.0005  0.0000  0.0000  0.1
#               0.0005 0.1    0.663266  0.768460  0.0005  0.0000  0.0005  0.1
#        0.0005 0.0000 0.1    0.671815  0.728882  0.0005  0.0005  0.0000  0.1
#               0.0005 0.1    0.662450  0.717772  0.0005  0.0005  0.0005  0.1
# 0.0050 0.0000 0.0000 0.1    0.676770  0.737449  0.0050  0.0000  0.0000  0.1
#               0.0050 0.1    0.682855  0.749496  0.0050  0.0000  0.0050  0.1
#        0.0050 0.0000 0.1    0.706941  0.743455  0.0050  0.0050  0.0000  0.1
#               0.0050 0.1    0.692458  0.771465  0.0050  0.0050  0.0050  0.1

# %%
top_performers_same_params = best_runs.groupby(['corr', 'diff', 'ssim', 'div']).apply(lambda x: x.loc[x['fc_diff_val'].idxmin()])
top_performers_same_params
# Out:
#                           lat  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1   12
#               0.0005 0.1   16
#               0.0050 0.1   14
#        0.0005 0.0000 0.1   15
#               0.0005 0.1   11
#        0.0050 0.0000 0.1    7
#               0.0050 0.1   14
# 0.0005 0.0000 0.0000 0.1   14
#               0.0005 0.1   12
#        0.0005 0.0000 0.1   10
#               0.0005 0.1   14
# 0.0050 0.0000 0.0000 0.1   11
#               0.0050 0.1   14
#        0.0050 0.0000 0.1   15
#               0.0050 0.1   12
#
#                                                                 file_name  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1                 mse_corr0_diff0_ssim0_div0.1.csv
#               0.0005 0.1            mse_corr0_diff0_ssim0.0005_div0.1.csv
#               0.0050 0.1             mse_corr0_diff0_ssim0.005_div0.1.csv
#        0.0005 0.0000 0.1            mse_corr0_diff0.0005_ssim0_div0.1.csv
#               0.0005 0.1       mse_corr0_diff0.0005_ssim0.0005_div0.1.csv
#        0.0050 0.0000 0.1             mse_corr0_diff0.005_ssim0_div0.1.csv
#               0.0050 0.1         mse_corr0_diff0.005_ssim0.005_div0.1.csv
# 0.0005 0.0000 0.0000 0.1            mse_corr0.0005_diff0_ssim0_div0.1.csv
#               0.0005 0.1       mse_corr0.0005_diff0_ssim0.0005_div0.1.csv
#        0.0005 0.0000 0.1       mse_corr0.0005_diff0.0005_ssim0_div0.1.csv
#               0.0005 0.1  mse_corr0.0005_diff0.0005_ssim0.0005_div0.1.csv
# 0.0050 0.0000 0.0000 0.1             mse_corr0.005_diff0_ssim0_div0.1.csv
#               0.0050 0.1         mse_corr0.005_diff0_ssim0.005_div0.1.csv
#        0.0050 0.0000 0.1         mse_corr0.005_diff0.005_ssim0_div0.1.csv
#               0.0050 0.1     mse_corr0.005_diff0.005_ssim0.005_div0.1.csv
#
#                           train_loss  val_loss  fc_diff_train  fc_diff_val  \
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1    0.293557  0.257944       0.038378     0.017529
#               0.0005 0.1    0.297727  0.262251       0.042987     0.019023
#               0.0050 0.1    0.269638  0.235933       0.043504     0.019354
#        0.0005 0.0000 0.1    0.250726  0.211179       0.034824     0.016137
#               0.0005 0.1    0.311381  0.284228       0.042672     0.019437
#        0.0050 0.0000 0.1    0.425815  0.397740       0.074891     0.024668
#               0.0050 0.1    0.255772  0.220148       0.041344     0.016828
# 0.0005 0.0000 0.0000 0.1    0.256543  0.209588       0.038311     0.018061
#               0.0005 0.1    0.286353  0.251982       0.042611     0.017668
#        0.0005 0.0000 0.1    0.329901  0.299173       0.048861     0.020257
#               0.0005 0.1    0.278172  0.242893       0.037857     0.023356
# 0.0050 0.0000 0.0000 0.1    0.309297  0.274103       0.046060     0.018986
#               0.0050 0.1    0.258150  0.227930       0.045178     0.020162
#        0.0050 0.0000 0.1    0.237035  0.198275       0.041711     0.020396
#               0.0050 0.1    0.289399  0.255598       0.042448     0.018689
#
#                           corr_train  corr_val    corr    diff    ssim  div
# corr   diff   ssim   div
# 0.0000 0.0000 0.0000 0.1    0.694973  0.762429  0.0000  0.0000  0.0000  0.1
#               0.0005 0.1    0.680534  0.721974  0.0000  0.0000  0.0005  0.1
#               0.0050 0.1    0.700798  0.758743  0.0000  0.0000  0.0050  0.1
#        0.0005 0.0000 0.1    0.699583  0.780684  0.0000  0.0005  0.0000  0.1
#               0.0005 0.1    0.680807  0.720522  0.0000  0.0005  0.0005  0.1
#        0.0050 0.0000 0.1    0.576361  0.712420  0.0000  0.0050  0.0000  0.1
#               0.0050 0.1    0.681446  0.756508  0.0000  0.0050  0.0050  0.1
# 0.0005 0.0000 0.0000 0.1    0.695951  0.764503  0.0005  0.0000  0.0000  0.1
#               0.0005 0.1    0.663266  0.768460  0.0005  0.0000  0.0005  0.1
#        0.0005 0.0000 0.1    0.632849  0.706591  0.0005  0.0005  0.0000  0.1
#               0.0005 0.1    0.691133  0.688590  0.0005  0.0005  0.0005  0.1
# 0.0050 0.0000 0.0000 0.1    0.676770  0.737449  0.0050  0.0000  0.0000  0.1
#               0.0050 0.1    0.682855  0.749496  0.0050  0.0000  0.0050  0.1
#        0.0050 0.0000 0.1    0.706941  0.743455  0.0050  0.0050  0.0000  0.1
#               0.0050 0.1    0.670837  0.740005  0.0050  0.0050  0.0050  0.1

# %%
# TODO: add the mse_corr.csv etc files to the dataframe
